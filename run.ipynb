# %%
from util.create_map import create_map
from search import Search

# %reload_ext autoreload
# %autoreload 2

# %%
map1 = create_map(10, 15, d=0.3)
map1.plot_map()

# %%
map1.plot_graph()

# %%
search = Search()

# %% [markdown]
# ## BFS

# %%
search.bfs(map1)
# Out:
# Found in (9, 5) || 45 steps

# %%
search.plot_progress()

# %% [markdown]
# ## DFS

# %%
search.dfs(map1)
# Out:
# Found in (9, 5) || 83 steps

# %%
search.plot_progress()

# %% [markdown]
# ## A*

# %%
search.astar(map1)
# Out:
# Found at (9, 5) || 14 steps

# %%
search.plot_progress()
