# %%
from util.create_map import create_map
from search import Search

# %reload_ext autoreload
# %autoreload 2

# %%
map1 = create_map(20, 20, d=0.4)
map1.plot_map()

# %%
map1.plot_graph()

# %%
search = Search()

# %% [markdown]
# ## BFS

# %%
search.bfs(map1)
# Out:
# Found in (11, 19) || 166 steps

# %%
search.plot_progress()

# %% [markdown]
# ## DFS

# %%
search.dfs(map1)
# Out:
# Found in (11, 19) || 36 steps

# %%
search.plot_progress()

# %% [markdown]
# ## A*

# %%
search.astar(map1)
# Out:
# Found at (11, 19) || 66 steps

# %%
search.plot_progress()
