# %%
from search_algorithms import Search
from util.create_map import create_map

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## BFS

# %%
map1 = create_map(10, 10, d=0.3, close=True)
map1.plot()

# %%
search = Search()
progress = search.bfs(map1)
# Out:
# Found at (5, 6) || 22 steps

# %%
search.plot_progress(progress)

# %% [markdown]
# ## DFS

# %%
map2 = create_map(10, 10, d=0.4)
map2.plot()

# %%
search = Search()
progress2 = search.dfs(map2)
# Out:
# Found at (8, 3) || 20 steps

# %%
search.plot_progress(progress2)
