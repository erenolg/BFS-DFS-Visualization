# %%
from util.create_map import create_map
from util.map_to_graph import Map2Graph
import networkx as nx

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
map1 = create_map(10, 10, d=0.4)
map1.plot()

# %%
map2graph = Map2Graph()

# %%
graph1 = map2graph.to_graph(map1)

# %%
graph1.display()

# %%
nx.shortest_path_length(graph1, (1,1), (7,8))
# Out:
# 17
